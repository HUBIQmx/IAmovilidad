# %% [markdown]
# # Regresión lineal - Regularización Ridge
#
# ## Formula
#
# $ y = \theta_0 + \theta_1 x + \theta_2 x^2$

# %%
# Librerias

import matplotlib.pyplot as plt
import numpy as np

# %%
# Datos
from sklearn import datasets
xT, y = datasets.load_diabetes(return_X_y=True)
x = xT[:,6]
m = x.size
plt.plot(x,y,'o')

# %%
### Aprendizaje 
from sklearn import linear_model

from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2, include_bias=False)


X = x.reshape(-1,1)
Y = y.reshape(-1,1)

Xpoly = poly.fit_transform(X)

modeloRL = linear_model.LinearRegression()
modeloRL.fit(Xpoly,Y)
print(" Modelo 1 Sklearn ")
print("theta0: ", modeloRL.intercept_)
print("theta1-2: ", modeloRL.coef_)
# Out:
#  Modelo 1 Sklearn
# theta0:  [148.33615268]
# theta1-2:  [[-702.73652288 1678.42051567]]

# %%
# Predicción scikit-learn
plt.plot(X,Y,'o')
plt.plot(X,modeloRL.intercept_ + modeloRL.coef_[0,0]*X + modeloRL.coef_[0,1]*X**2,'o') 
plt.show()

# %%
# Aprendizaje con regularización Ridge
from sklearn.linear_model import Ridge
modelo = Ridge(alpha=1.0)

modelo.fit(Xpoly, Y)
# Out:
# Ridge()

# %%
print(" Modelo Sklearn ")
print("theta0: ", modelo.intercept_)
print("theta1: ", modelo.coef_)
# Out:
#  Modelo Sklearn
# theta0:  [152.14088078]
# theta1:  [[-319.51070669   -3.2693043 ]]

# %%
# Predicción scikit-learn
plt.plot(X,Y,'o')
plt.plot(X,modelo.intercept_ + modelo.coef_[0,0]*X + modelo.coef_[0,1]*X**2,'o') 
plt.show()
