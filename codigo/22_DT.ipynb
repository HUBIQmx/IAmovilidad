# %% [markdown]
# ## Árboles de decisión

# %%
# Librerias
from sklearn.preprocessing import StandardScaler
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import tree
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(1)

X, y = datasets.load_wine(return_X_y=True)
variables = datasets.load_wine().feature_names
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Scaling data
scaler1 = StandardScaler() 
scaler1.fit(X_train)  
X_train = scaler1.transform(X_train)  

scaler2 = StandardScaler() 
scaler2.fit(X_test)  
X_test = scaler2.transform(X_test)

# %%
modelo = tree.DecisionTreeClassifier(criterion='entropy', max_depth=3)
modelo.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
print(tree.export_text(modelo, feature_names=variables))
# Out:
# |--- flavanoids <= -0.40
# |   |--- color_intensity <= -0.51
# |   |   |--- class: 1
# |   |--- color_intensity >  -0.51
# |   |   |--- hue <= -0.06
# |   |   |   |--- class: 2
# |   |   |--- hue >  -0.06
# |   |   |   |--- class: 1
# |--- flavanoids >  -0.40
# |   |--- proline <= 0.05
# |   |   |--- alcohol <= 0.23
# |   |   |   |--- class: 1
# |   |   |--- alcohol >  0.23
# |   |   |   |--- class: 1
# |   |--- proline >  0.05
# |   |   |--- alcohol <= -0.42
# |   |   |   |--- class: 1
# |   |   |--- alcohol >  -0.42
# |   |   |   |--- class: 0

# %%
tree.plot_tree(modelo, feature_names=variables)
plt.show()

# %%
#tree.export_graphviz(modelo, out_file='arbol_vino.dot')
